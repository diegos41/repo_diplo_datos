# %% [markdown]
# *Mini desafío teórico GitHub*

# %%
#Este código no permite realizar la operación una vez que se ingresaron los datos nuevamente 
#y son correctos. Ver el código próximo (solución propuesta).
print("Secuencia de números")
A=int(input("Ingrese el primer número: "))
B=int(input("Ingrese el segundo número: "))

if A<=B:
    while A<=B:
      print(A)
      A+=1
else:
    while B<=A:
      B=int(input("Segundo número no válido. Ingreselo nuevamente: "))
# Out:
# Secuencia de números
# Ingrese el primer número: 1
# Ingrese el segundo número: 0
# Segundo número no válido. Ingreselo nuevamente: 0
# Segundo número no válido. Ingreselo nuevamente: 0
# Segundo número no válido. Ingreselo nuevamente: 3

# %%
#Si bien funciona, debería pedirme solo el valor de B nuevamente.
LosNumerosSonCorrectos = False

while (LosNumerosSonCorrectos == False):
  
      A = int(input("Ingrese valor A: "))
      B = int(input("Ingrese valor B: "))

      if (B >= A):
        LosNumerosSonCorrectos = True
        
      else: 
          print("Los numeros no son correctos, B tiene que ser mayor que A")
          print("Ingrese los valores nuvamente: ")
        

while (A <= B):
  print(A)
  A += 1
# Out:
# Ingrese valor A: 2
# Ingrese valor B: 1
# Los numeros no son correctos, B tiene que ser mayor que A
# Ingrese los valores nuvamente:
# Ingrese valor A: 3
# Ingrese valor B: 6
# 3
# 4
# 5
# 6

# %% [markdown]
# **2.**

# %%
#Este es usando el continue statement
print("Secuencia:")
x=1
y=1
while x>=0:
  print (x)
  x+=y
  if x==5:
    y=-1
    continue
# Out:
# Secuencia:
# 1
# 2
# 3
# 4
# 5
# 4
# 3
# 2
# 1
# 0

# %%
print("Sequence:")
x=1
y=1
while x>=0:
  if x>=1 and x<=4:
    print(x)
    x+=y
  else:
    y=-1
    print(x)
    x+=y
# Out:
# Sequence:
# 1
# 2
# 3
# 4
# 5
# 4
# 3
# 2
# 1
# 0

# %%
#Mejorado
print("Sequence:")
x=1
y=1
while x>=0:
 if x<=4:
  print(x)
  x+=y
 else:
  y=-1
  print(x)
  x+=y
# Out:
# Sequence:
# 1
# 2
# 3
# 4
# 5
# 4
# 3
# 2
# 1
# 0

# %%
#Solución propuesta
x = 1

while x <= 10:
    if x < 6:
        print(x)
    else:
        print(10-x)
    x+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 4
# 3
# 2
# 1
# 0
