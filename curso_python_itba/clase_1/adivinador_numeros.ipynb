# %%
#Intenté hacer algo parecido al método de bisección pero no salió.
#Versiones anteriores funcionaban pero variaban con números fijos aleatorios.
i=0
j=0
ult=0
ault=0
n=5000 

x0=input("¿Es cero? ")
if x0=="=":
  print(i)

else:
  while n>0: 
    print(n)
    x=input("¿Es mayor, menor o igual a dicho número?:" )
    if x=="<":
      if i==0 and j>=0:
        j+=1
        #ult=n
        n=n//2
      else:
        i+=1
        n=(n+ult)//2
    elif x==">":
      i+=1
      if i==1 and j==0:                   #al primer > necesito correrle la escala para que trabaje en nros >5000.
        #ult=n
        n=n//2+5000
      elif ult<n:
        #ault=ult
        #ult=n
        n=(ult+n)//2
      else:
        #ault=ult
        #ult=n
        s=(ault+ult)//2
        n=s+2*(ult-s)

    elif x=="=":
      print(i+j)
      break
    else:
      print("La respuesta ingresada no es válida.")
      continue

if i>=2 or j>=2: 
  ault=ult
ult=n
