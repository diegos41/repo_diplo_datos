# %% [markdown]
# *Mini desafío propuesto en el teórico de GitHub*

# %%
print("Calculadora de media geométrica")
x=int(input("Ingrese el primer número: "))
y=x=int(input("Ingrese el segundo número: "))
z=x=int(input("Ingrese el tercer número: "))

x=(x*y*z)**(1/3)

print("Resultado:", x)
# Out:
# Calculadora de media geométrica
# Ingrese el primer número: 2
# Ingrese el segundo número: 2
# Ingrese el tercer número: 2
# Resultado: 2.0
