# %% [markdown]
# *Este ejercicio es el desafío propuesto en el video 5 de la Clase 1*

# %%
print("¿Qué dia de la samana cae?")
x= int(input("Ingrese un número de 0 a 364: "))
y= (x%7)
print(y)
# Out:
# ¿Qué dia de la samana cae?
# Ingrese un número de 0 a 364: 7
# 0

# %%
#Versión de 1 a 365
print("¿Qué dia de la samana cae?")
x= int(input("Ingrese un número de 1 a 365: "))
y= x%7

if y==0:
  print(7)
else:
  print(y)
# Out:
# ¿Qué dia de la samana cae?
# Ingrese un número de 1 a 365: 50
# 1

# %% [markdown]
# *Mini desafío del teórico en GitHub*

# %%
print("¿A qué hora llega el corredor a la meta?" )
x= int(input("Ingrese la cantidad de horas: "))
x= x%24

print("Resultado: ", x)
# Out:
# ¿A qué hora llega el corredor a la meta?
# Ingrese la cantidad de horas: 34
# Resultado:  10
